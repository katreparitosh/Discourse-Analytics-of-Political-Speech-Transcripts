# %%
import pandas as pd
import re
pd.options.display.max_columns = 30  #Can't have too many columns.
import glob
from datetime import datetime
import dateutil.parser
import nltk
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']= (17,5)
from collections import Counter
import re
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import re
from nltk.stem.porter import PorterStemmer
from sklearn.cluster import KMeans
import langid
from tqdm import tqdm
import os
import locale

# %%
#Checking if all the speeches are loaded or not
folder = nltk.data.find('A:/Data Analysis Jupyter/Campaign-Analytics/Speeches/narendramodi/2015/')
path_link = 'A:/Data Analysis Jupyter/Campaign-Analytics/Speeches/narendramodi/2015/*'
paths = glob.glob(path_link)
len(paths)
# Out:
# 148

# %%
nm_speeches = [ ]  #Empty dataframe to store all the content of speeches
for path in paths:
    corpusReader = nltk.corpus.PlaintextCorpusReader(folder, '.*\.txt')
    # opening the files and converting it to a dictionary
    with open(path, encoding="utf-8") as speech_file:
        filename = path.split('/')[-1]
        date = re.search(r"(_\d\d)_(\w+)_(\d\d\d\d)", filename) 
        if date:
            date = datetime.strptime(date.group(0), '_%d_%b_%Y')
        else:
            date = np.nan
        speech = {
            'Title' : path.split('/')[-1],
            'Speech' : speech_file.read(),
            'Date' : date
        }   
    nm_speeches.append(speech)
nm_df = pd.DataFrame(nm_speeches)
nm_df.head(10)
# Out:
#         Date                                             Speech  \
# 0 2015-05-31  My Dear Countrymen, Last time when I addressed...
# 1 2015-05-31  à¤®à¥à¤°à¥ à¤ªà¥à¤¯à¤¾à¤°à¥ à¤¦à¥à¤¶à¤µà¤...
# 2 2015-06-05  His Excellency Prime Minister Mr. Mark Rutte, ...
# 3 2015-06-06  Excellency, Prime Minister Sheikh Hasina,Membe...
# 4 2015-06-07  à¤à¤¦à¤°à¤£à¥à¤¯ à¤°à¤¾à¤·à¥à¤à¥à¤°à¤ªà¤¤...
# 5 2015-06-07  à¤¦à¥ à¤¦à¤¿à¤¨ à¤à¥ à¤®à¥à¤°à¥ à¤¯à¤¾à¤¤...
# 6 2015-06-19  Excellency President Jakaya Mrisho Kikwete, Me...
# 7 2015-06-21  à¤¦à¥à¤¶à¤­à¤° à¤®à¥à¤ à¤à¤° à¤µà¤¿à¤¶à¥â...
# 8 2015-06-21  Fellow practitioners of yoga assembled here to...
# 9 2015-06-25  आज इस एक छत के नीचे शहरी भारत इकठ्ठा हुआ है। U...
#
#                                                Title
# 0  2015\100_31_May_2015_English_Rendering_of_the_...
# 1  2015\101_31_May_2015_Text_of_PMs_Mann_ki_Baat_...
# 2  2015\102_05_Jun_2015_Text_of_the_PMs_statement...
# 3  2015\103_06_Jun_2015_Text_of_the_PMs_statement...
# 4  2015\104_07_Jun_2015_Text_of_PMs_acceptance_sp...
# 5  2015\105_07_Jun_2015_Text_of_PMs_address_at_Ba...
# 6  2015\106_19_Jun_2015_Text_of_PMs_media_stateme...
# 7  2015\107_21_Jun_2015_Text_of_PMs_address_at_th...
# 8  2015\108_21_Jun_2015_Text_of_PMs_remarks_at_In...
# 9  2015\109_25_Jun_2015_Text_of_PMs_remarks_at_th...

# %%
nm_df['Year'],nm_df['Month'],nm_df['Day'] = nm_df.Date.dt.year, nm_df.Date.dt.month, nm_df.Date.dt.day

# %%
nm_df.head()
# Out:
#         Date                                             Speech  \
# 0 2015-05-31  My Dear Countrymen, Last time when I addressed...
# 1 2015-05-31  à¤®à¥à¤°à¥ à¤ªà¥à¤¯à¤¾à¤°à¥ à¤¦à¥à¤¶à¤µà¤...
# 2 2015-06-05  His Excellency Prime Minister Mr. Mark Rutte, ...
# 3 2015-06-06  Excellency, Prime Minister Sheikh Hasina,Membe...
# 4 2015-06-07  à¤à¤¦à¤°à¤£à¥à¤¯ à¤°à¤¾à¤·à¥à¤à¥à¤°à¤ªà¤¤...
#
#                                                Title  Year  Month  Day
# 0  2015\100_31_May_2015_English_Rendering_of_the_...  2015      5   31
# 1  2015\101_31_May_2015_Text_of_PMs_Mann_ki_Baat_...  2015      5   31
# 2  2015\102_05_Jun_2015_Text_of_the_PMs_statement...  2015      6    5
# 3  2015\103_06_Jun_2015_Text_of_the_PMs_statement...  2015      6    6
# 4  2015\104_07_Jun_2015_Text_of_PMs_acceptance_sp...  2015      6    7

# %%
nm_df = nm_df[["Year","Month", "Day", "Title", "Speech", "Date"]]

# %%
nm_df.head()
# Out:
#    Year  Month  Day                                              Title  \
# 0  2015      5   31  2015\100_31_May_2015_English_Rendering_of_the_...
# 1  2015      5   31  2015\101_31_May_2015_Text_of_PMs_Mann_ki_Baat_...
# 2  2015      6    5  2015\102_05_Jun_2015_Text_of_the_PMs_statement...
# 3  2015      6    6  2015\103_06_Jun_2015_Text_of_the_PMs_statement...
# 4  2015      6    7  2015\104_07_Jun_2015_Text_of_PMs_acceptance_sp...
#
#                                               Speech       Date
# 0  My Dear Countrymen, Last time when I addressed... 2015-05-31
# 1  à¤®à¥à¤°à¥ à¤ªà¥à¤¯à¤¾à¤°à¥ à¤¦à¥à¤¶à¤µà¤... 2015-05-31
# 2  His Excellency Prime Minister Mr. Mark Rutte, ... 2015-06-05
# 3  Excellency, Prime Minister Sheikh Hasina,Membe... 2015-06-06
# 4  à¤à¤¦à¤°à¤£à¥à¤¯ à¤°à¤¾à¤·à¥à¤à¥à¤°à¤ªà¤¤... 2015-06-07

# %%
nm_df.to_pickle('speeches_df_2015.pkl')
